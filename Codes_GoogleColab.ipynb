# %% [markdown]
# <a href="https://colab.research.google.com/github/ladyjfuhrer/data-imputation/blob/main/Codes_GoogleColab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

datafile = pd.read_csv('/content/country_vaccination_stats.csv')

datafile.head()
# Out:
#      country        date  daily_vaccinations   vaccines
# 0  Argentina  12/29/2020                 NaN  Sputnik V
# 1  Argentina  12/30/2020             15656.0  Sputnik V
# 2  Argentina  12/31/2020             15656.0  Sputnik V
# 3  Argentina    1/1/2021             11070.0  Sputnik V
# 4  Argentina    1/2/2021              8776.0  Sputnik V

# %%
datafile.shape
datafile.info() #daily_vaccinations column has 60 missing index
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1502 entries, 0 to 1501
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   country             1502 non-null   object
#  1   date                1502 non-null   object
#  2   daily_vaccinations  1442 non-null   float64
#  3   vaccines            1502 non-null   object
# dtypes: float64(1), object(3)
# memory usage: 47.1+ KB

# %%
def fill_missing_vaccinations(datafile):

    min_vaccinations = datafile.groupby('country')['daily_vaccinations'].min()


    datafile['daily_vaccinations'] = datafile.apply(lambda row: min_vaccinations[row['country']] if pd.isna(row['daily_vaccinations']) else row['daily_vaccinations'], axis=1)


    datafile['daily_vaccinations'].fillna(0, inplace=True)

    return datafile


datafile_filled = fill_missing_vaccinations(datafile)

# %%
datafile.head()
# Out:
#      country        date  daily_vaccinations   vaccines
# 0  Argentina  12/29/2020              6483.0  Sputnik V
# 1  Argentina  12/30/2020             15656.0  Sputnik V
# 2  Argentina  12/31/2020             15656.0  Sputnik V
# 3  Argentina    1/1/2021             11070.0  Sputnik V
# 4  Argentina    1/2/2021              8776.0  Sputnik V

# %%
datafile_filled.to_csv('filled_dataset.csv', index=False)

# %%
datafile_last = pd.read_csv('filled_dataset.csv')

median_daily_vaccinations = datafile_last.groupby('country')['daily_vaccinations'].median()

sorted_countries = median_daily_vaccinations.sort_values(ascending=False)

top_3_countries = sorted_countries.head(3)

print("Top 3 countries with highest median daily vaccination numbers:", top_3_countries)
# Out:
# Top 3 countries with highest median daily vaccination numbers: country
# United States    378253.0
# China            276786.0
# India            173922.0
# Name: daily_vaccinations, dtype: float64

# %%
# converting the date column to datetime format
datafile_last['date'] = pd.to_datetime(datafile_last['date'])

# %%
#filtering
vacc_01062021 = datafile_last[datafile_last['date'] == '2021-01-06']

# %%
total_vacc_01062021 = vacc_01062021['daily_vaccinations'].sum()

print(total_vacc_01062021)
# Out:
# 1485255.0
